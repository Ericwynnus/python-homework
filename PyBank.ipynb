# %%
#Step 1 Import My Data
#Your task is to create a Python script that analyzes the records to calculate each of the following:

from pathlib import Path
import csv

#csvpath = Path(r"C:\Users\13212\Desktop\Fintech\uofm-virt-fin-pt-12-2021-u-c\02-Homework\02-Python\Instructions\PyBank\Resources\budget_data.csv")
csvpath = Path("budget_data.csv")
profit_loss = []

line_num = 0

with open(csvpath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter =',')
    header = next(csvreader)
    line_num += 1
    for row in csvreader:
        profit_losses = int(row[1])
        profit_loss.append(profit_losses)
    
#Initialize my counts:
counts = 0
total = 0
average = 0
minimum = 0
maximum = 0
day = 0

#These are not working, so I am defering to Section 2 Python2/activites (see above)
Total_Months = 0
StepTotal = 0
Average_Change = 0
Greatest_Increase_in_Profits = 0
Greatest_Decrease_in_Profits = 0
day_count = 0

#Step 2 
#The total number of months included in the dataset.
#error noted: Come back to this section.
#for row in total:
#    Financial_total += total
#    total += 1
 
#Step 3 
#The net total amount of Profit/Losses over the entire period.
profitable_months = []
unprofitable_months = []

for month_pnl in profit_loss:
    total += month_pnl
    counts += 1
    if minimum == 0:
        minimum = month_pnl
    elif month_pnl < minimum:
        minimum = month_pnl
    elif month_pnl > maximum:
        maximum = month_pnl

#Step 4 The average of the changes in Profit/Losses over the entire period.        
total_profits = []
total_losses = []
     
average = round(total/counts, 2)

#Step 5 The greatest increase in profits (date and amount) over the entire period.
if minimum == 0:
    minimum = Greatest_Increase_in_Profits
elif Greatest_Increase_in_Profits > minimum:
    minimum = Greatest_Increase_in_Profits

#Step 6 The greatest decrease in losses (date and amount) over the entire period.
if minimum == 0:
    minimum = total_losses
elif losses < minimum:
    minimum = total_profits

#7 Your resulting analysis should look similar to the following:
#Financial Analysis
string="Financial_Analysis"
print("Financial Analysis")
String="-------------------"
print ("-------------------")
string="Total_Months:"
print(f"Total Months:{counts}")
string="Total:"
print(f"Total: {total}")
string="Average_Change:"
print(f"Average Change:{average}")
string="Greatest_increase_in_Profits"
print(f"Greatest Increase in Profits:{day_count, minimum}")
string="Greatest_Decrease_In_Profits"
print(f"Greatest Decrease In Profits:{day_count, maximum}")
# Out:
# Financial Analysis
# -------------------
# Total Months:86
# Total: 38382578
# Average Change:446309.05
# Greatest Increase in Profits:(0, [])
# Greatest Decrease In Profits:(0, 1170593)
